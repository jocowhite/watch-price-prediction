# %% [markdown]
# # Data
#
# To solve the problem, three data sets were compiled and downloaded.
# The first dataset is an official dataset from Kaggle, which is freely accessible.
#
# ## DS_1 [Kaggle - A Dataset of Watches](https://www.kaggle.com/datasets/mathewkouch/a-dataset-of-watches)
#
# This dataset includes 2553 watch images and additional information about the brand to the name of the watch and the price in US dollars. At the time of writing, there are no public code samples for the dataset.
#
# ## DS_2 Scraped OnlineShop [Marc Gebauer](https://marcgebauer.com/collections/alle-luxus-uhren)
#
# With the help of the [GITHub Shopify Scraper](https://github.com/lagenar/shopify-scraper) which was minimally adapted, 230 watch images from the Marc Gebauer Shop were scraped. In addition, the scraper could also record the prices of the products and save them in a CSV.
#
# ## DS_3 Scraped OnlineShop [Crown & Caliber](https://www.crownandcaliber.com/)
# Also with the help of the customised [GITHub Shopify Scraper](https://github.com/lagenar/shopify-scraper), 26,216 watch images and their prices could be scraped in this online shop.

# %%
### Imports for this Notebook
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker 
import pandas as pd
import numpy as np

import os
import urllib.request 
import concurrent.futures

# %% [markdown]
# ## Get Kaggle Data
# Download the Data from Kaggle and extract the ZIP.
# If you extract the ZIP and put the result inside the data foulder you can run the following comands from the terminal if yout terminal is located in the directory folder.
# ```bash
#    cp data/metadata/archive/watches/watches/metadata.csv data/metadata/
#    cp -r data/metadata/archive/watches/watches/images data/watches/ds1_kaggle
#    rm -r data/metadata/archive
# ```

# %% [markdown]
# # Scraper

# %% [markdown]
# ### Scrape Products from Shops with [GitHub Scraper](https://github.com/lagenar/shopify-scraper)

# %%
from shopify_scraper import extract_products

# %%
# check in the output csv if you got your expected result 
# and stop the scaper manualy when you get no more shop items or you got blocked
extract_products("https://marcgebauer.com", 'data/metadata/marc_products.csv')

# %%
### This cell would take very long because the crown caliber shop has over 20k watches 
#extract_products("https://www.crownandcaliber.com", 'data/metadata/crown_products.csv')

# %% [markdown]
# ## Download images from the shops

# %%
def get_picture(row, folder):
    url = row[1]["Image URL"]
    code = row[1]["Code"]
    
    try:
        # Bild herunterladen und speichern
        image_filename = "data/watches/" + folder + f"/images/{code}.jpg"
        urllib.request.urlretrieve(url, image_filename)
        return "Bild gespeichert:" + image_filename
    except Exception as e:
        return "Fehler beim Herunterladen des Bildes:" +  url +  "Fehlermeldung:" +  str(e)
    
def download_images(df, folder):
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:

        future_row = [executor.submit(get_picture, row, folder) for row in df.iterrows()]

        for future in concurrent.futures.as_completed(future_row):
            try:
                print(future.result())
            except Exception as exc:
                print(f"Fehler: {exc}")

# %%
### TIME INFORMATION: needs X,X Minutes to run
df_marc = pd.read_csv("data/metadata/marc_products.csv")
#read only watches
df_marc = df_marc[df_marc['Category'] == 'Uhren']
download_images(df_marc, "ds2_marc")
# Out:
# Bild gespeichert:data/watches/ds2_marc/images/MG03280.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG220623.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01804.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03157.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01937.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5345S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02987.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02037.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01339.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01987.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03073.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02356.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG219023.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02441.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02221.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG219623.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03085.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03261.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01441.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03254.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01439.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG210823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01440.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02607.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03057.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02447.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03084.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02820.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02967.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02997.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03258.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03292.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03059.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03289.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02798.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01826.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03162.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03165.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG228423.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5347S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03259.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG216123.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03041.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02973.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03257.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG200823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5330S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02969.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03032.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03164.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03089.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03033.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03252.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01730.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03078.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03097.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02620.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02758.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03302.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03271.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02986.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03046.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03029.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03099.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02662.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02373.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03290.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02988.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02621.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02271.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02305.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG216323.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01936.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG216823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5305S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01532.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01636.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG220723.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02772.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03247.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02826.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01938.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02432.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02776.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01939.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01634.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03170.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5303S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01678.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03228.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5349S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02259.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG228523.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03215.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02227.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03216.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01633.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5381S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02052.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5407S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223323.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223123.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG228723.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5321S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5312S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5339S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223923.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5340S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5314S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG222823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5327S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223523.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5356S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223623.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223723.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223023.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223423.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG223223.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5316S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5332S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5317S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5315S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG222923.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG222723.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01724.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02634.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG228223.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03095.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03244.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03103.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02929.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02855.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02762.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03248.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02749.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02092.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03013.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01374.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01442.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5285S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01468.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02822.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02725.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5489S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02730.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG215823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01935.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01438.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03227.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5343S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01662.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG220823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01806.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02633.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03168.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03080.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03210.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5286S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG227923.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03211.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01338.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5294S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03022.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG219723.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03229.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5291S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5288S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03023.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02788.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03075.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01546.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03105.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5324S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03293.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03159.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02841.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01632.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG228123.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG215023.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03158.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02985.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02342.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02629.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01419.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5301S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02032.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01916.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02205.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03232.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03208.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02813.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03231.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02204.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02747.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03205.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02019.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03202.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03207.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02801.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03048.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03167.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03200.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02974.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03020.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02461.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01778.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01962.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02451.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02455.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01850.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02457.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01505.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG228023.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01507.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03196.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03104.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01510.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03245.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03092.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02800.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03071.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG4243S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG217823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02025.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG217023.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG224023.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG222623.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG217223.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5435S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5353S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01443.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG217123.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG03068.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5436S.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG217923.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01422.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02438.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01563.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG219123.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG212823.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG01341.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG02372.jpg
# Bild gespeichert:data/watches/ds2_marc/images/MG5439S.jpg

# %%
### This cell would take very long because the crown caliber shop has over 20k watches 
#df_crown = pd.read_csv("data/metadata/marc_products.csv")
#download_images(df_crown, "ds3_crown")

# %% [markdown]
# # Data Preperation

# %%
## Helperfunctions

### Change the used filetype here
def add_jpg_suffix(string):
    return string + '.jpg'

### You can change the conversion rate here
def convert_usd_to_eur(price):
    return '%.2f' % (price * 1.0675)

# %%
def format_data(df, drop_colums = None,
                      replace_stringparts = None, 
                      convert_price = None,
                      convert_to_usd = False,
                      select_category= None,
                      create_path_from_name = False,
                      reindex = None):

    #Choose a category from the Shopify Shop Categories if the Shop has not only watches
    if select_category != None:
        df = df[df['Category'] == select_category]
    
    #Drop the columns we don't need for the Model
    if drop_colums != None:
        df = df.drop(drop_colums, axis=1)
    
    #Replace unnecessary string parts in the Price String of the Kaggle Data
    if replace_stringparts != None:
        for replace_object in replace_stringparts:
            df['price'] = df['price'].replace(replace_object , '', regex=True)
    
    #Convert the Price to a specific Datatype
    if convert_price != None:
        df["price"].astype(float)
        
    #Convert the price from eur to usd
    if convert_to_usd:
        df['price'] = df['price'].apply(convert_usd_to_eur)
        
    #Add the needed colum where the image is stored
    if create_path_from_name:
        df['image_name'] = df['Code'].apply(add_jpg_suffix)
        
    #reindex the 
    if reindex != None:
        df = df.reindex(columns=reindex)

    return df

# %%
#this function checks if all files that are in the csv are stored in the images folder 
# otherwise it will be removed from the dataframe to prevent problems
def remove_nonexisting(path_to_cleandata, path_to_images):
    df = pd.read_csv(path_to_cleandata, index_col=0)
    #Get all Filenames in Image Folder
    file_names = []
    for filename in os.listdir(path_to_images):
        if os.path.isfile(os.path.join(path_to_images, filename)): 
            file_names.append(filename)
            #Remove non existing Pictures from Dataframe
    for index, row in df.iterrows():
        if row['image_name'] not in file_names:
            df.drop(index, inplace=True) 
    
    df = df.to_csv(path_to_cleandata)

# %% [markdown]
# ## Clean DS1 Kaggle Data

# %%
df_kaggle = pd.read_csv("data/metadata/metadata.csv") 
df_kaggle = format_data(df_kaggle,
                        replace_stringparts=["\$", " ", "'", '"', ","],
                        convert_price=True,
                        drop_colums=["brand", "name"],
                        reindex=['image_name', 'price'],
                       )
df_kaggle.to_csv("data/watches/ds1_kaggle/cleandata.csv")
remove_nonexisting(path_to_cleandata="data/watches/ds1_kaggle/cleandata.csv",
                   path_to_images="data/watches/ds1_kaggle/images"
                  )
df_kaggle.head()
# Out:
#   image_name    price
# 0      0.jpg  2780.00
# 1      1.jpg   449.95
# 2      2.jpg   399.00
# 3      3.jpg   349.00
# 4      4.jpg   549.00

# %% [markdown]
# ## Clean DS2 Marc Gebauer Products

# %%
df_marc = pd.read_csv("data/metadata/marc_products.csv")
df_marc = format_data(df_marc,
                        select_category='Uhren',
                        create_path_from_name=True,
                        convert_to_usd=True,
                        reindex=['image_name', 'price'],
                        drop_colums=['Name', 'URL', 'Image URL','Collection', 'Category', 'Variant Name', 'In Stock'])
df_marc.to_csv("data/watches/ds2_marc/cleandata.csv")
remove_nonexisting(path_to_cleandata="data/watches/ds1_kaggle/cleandata.csv",
                   path_to_images="data/watches/ds1_kaggle/images"
                  )
df_marc.head()
# Out:
#        image_name     price
# 0     MG01804.jpg  85389.32
# 783  MG220623.jpg   9063.07
# 785   MG03157.jpg  12158.82
# 786  MG219023.jpg  19204.32
# 787   MG03280.jpg  24541.82

# %% [markdown]
# ## Clean DS3 Crown Caliber Products

# %%
df_crown = pd.read_csv("data/metadata/crown_products.csv")
df_crown = format_data(df_crown,
                        create_path_from_name=True,
                        reindex=['image_name', 'price'],
                        drop_colums=['Name', 'URL', 'Image URL','Collection', 'Category', 'Variant Name', 'In Stock'])
df_crown.to_csv("data/watches/ds3_crown/cleandata.csv")
remove_nonexisting(path_to_cleandata="data/watches/ds3_crown/cleandata.csv",
                   path_to_images="data/watches/ds3_crown/images"
                  )
df_crown.head()
# Out:
#              image_name   price
# 0  10-20-CAR-9GQNYX.jpg  3250.0
# 1  10-10-AUD-41X7PK.jpg  1250.0
# 2  10-10-AUD-YTBX9H.jpg  1912.5
# 3  10-10-BAL-7NE1ZY.jpg  1905.0
# 4  10-10-BAL-AS5BMK.jpg  1478.0

# %% [markdown]
# # First Data Inspection

# %%
df_kaggle = pd.read_csv("data/watches/ds1_kaggle/cleandata.csv", index_col=0) 
df_marc = pd.read_csv("data/watches/ds2_marc/cleandata.csv", index_col=0) 
df_crown = pd.read_csv("data/watches/ds3_crown/cleandata.csv", index_col=0)
fig, ax = plt.subplots(figsize=(12, 6))
ax.boxplot([df_kaggle['price'],df_marc['price'],df_crown['price']],
           vert=False,
           labels=["Kaggle Data", "Marc Gebauer", "Crowns and Caliber"]
          )

ax.set_xscale('log')
plt.xscale('log')
ax.xaxis.set_major_formatter(ticker.ScalarFormatter()) 
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{int(x)}"))
plt.show()

# %% [markdown]
# Through an initial analysis of the data, it can be determined that the data sets are in different price ranges. It becomes particularly interesting to compare models that have been trained on a different data set.
